# %%
import matplotlib.pyplot as plt
from sklearn import linear_model
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("C:\logistica_diabetes.csv")

# %%
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
data = pd.read_csv("C:\logistica_diabetes.csv", sep = ",")

# %%
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
data[['Age','Outcome']].head()
# Out:
#    Age  Outcome
# 0   50        1
# 1   31        0
# 2   32        1
# 3   21        0
# 4   33        1

# %%
data[['Age','Outcome']].plot.scatter(x='Age',y='Outcome')
# Out:
# <Axes: xlabel='Age', ylabel='Outcome'>

# %%
regresion = linear_model.LinearRegression()
X_data = np.array(data['Age']).reshape((-1, 1))
Y_data = np.array(data['Outcome'])
modelo = regresion.fit(X_data, Y_data)
print ("Interseccion (b)", modelo.intercept_)
print ("Pendiente (m)", modelo.coef_)
# Out:
# Interseccion (b) 0.02762418861171162
# Pendiente (m) [0.00966683]

# %%
m = modelo.coef_
b = modelo.intercept_
x = np.linspace(30,data['Age'].max(),80)
y = 1/(1+np.exp(-(m*x+b)))

# %%
data.plot.scatter(x='Age',y='Outcome')
plt.plot(x, y, '-r')
plt.ylim(0,data['Outcome'].max()*1.1)
plt.show()
